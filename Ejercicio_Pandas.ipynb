# %% [markdown]
# <a href="https://colab.research.google.com/github/Laurarpoa/Grupo-de-trabajo-/blob/main/Ejercicio_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
Pacientes_Info_Primaria1 = pd.DataFrame({
    'Nombre': ['Marcela', 'José', 'Fernando', 'Camila', 'Luisa', 'Estefanía', 'Orlando', 'Socorro', 'Ashley', 'William', 'Manuela', 'Esteban', 'Juan', 'Laura', 'Alexis'],
    'Edad': [85, 20, 39, 15, 44, 56, 67, 9, 23, 33, 50, 10, 67, 78, 26],
    'Estatura': [1.68, 1.80, 1.60, 1.45, 1.65, 1.55, 1.78, 1.37, 1.70, 1.82, 1.50, 1.32, 1.51, 1.62, 1.74],
    'Medicamento': ['Losartán', 'Sertralina', 'Metformina', 'Omeprazol', 'Atenolol', 'Insulina', 'Atorvastatina', 'Paracetamol', 'Clonazepam', 'Pregabalina', 'Furosemida', 'Loratadina', 'Metoprolol', 'Enalapril', 'Azitromicina']
})

Pacientes_Info_Secundaria1 = pd.DataFrame({
    'Barrio': ['Belén', 'Laureles', 'Aranjuez', 'Robledo', 'Buenos Aires', 'Castilla', 'Poblado', 'Villa Hermosa', 'San Javier', 'Doce de Octubre', 'Villa Hermosa', 'Santa Cruz', 'Colores', 'San Javier', 'Belén'],
    'Estrato': [4, 5, 2, 3, 2, 2, 6, 2, 2, 2, 2, 2, 4, 2, 4],
    'Precio Tratamiento Completo (USD)': [86.40, 108.23, 72.70, 64.80, 82.80, 316.80, 118.80, 46.80, 100.50, 190.80, 57.60, 72.50, 72.50, 79.20, 86.40]
})

Prod_Farmacia1 = pd.DataFrame({
    'Medicamento': ['Losartán', 'Sertralina', 'Metformina', 'Omeprazol', 'Atenolol', 'Insulina', 'Atorvastatina', 'Paracetamol', 'Clonazepam', 'Pregabalina','Furosemida', 'Loratadina', 'Metoprolol', 'Enalapril', 'Azitromicina'],
    'Tipo': ['Antihipertensivo', 'Antidepresivo', 'Antidiabético', 'Gastroprotector', 'Betabloqueador','Antidiabético', 'Anticolesterol', 'Analgésico', 'Ansiolítico', 'Neuropático','Diurético', 'Antialérgico', 'Betabloqueador', 'Antihipertensivo', 'Antibiótico'],
    'Stock': [120, 80, 150, 200, 90, 60, 110, 300, 100, 70, 130, 180, 95, 105, 85],
    'Precio_Unitario_USD' : [0.24, 0.30, 0.20, 0.18, 0.23, 0.88, 0.33, 0.13, 0.28, 0.53, 0.16, 0.20, 0.20, 0.22, 0.24]
})


print(Pacientes_Info_Primaria1)
print(Pacientes_Info_Secundaria1)
print(Prod_Farmacia1)
# Out:
#        Nombre  Edad  Estatura    Medicamento
# 0     Marcela    85      1.68       Losartán
# 1        José    20      1.80     Sertralina
# 2    Fernando    39      1.60     Metformina
# 3      Camila    15      1.45      Omeprazol
# 4       Luisa    44      1.65       Atenolol
# 5   Estefanía    56      1.55       Insulina
# 6     Orlando    67      1.78  Atorvastatina
# 7     Socorro     9      1.37    Paracetamol
# 8      Ashley    23      1.70     Clonazepam
# 9     William    33      1.82    Pregabalina
# 10    Manuela    50      1.50     Furosemida
# 11    Esteban    10      1.32     Loratadina
# 12       Juan    67      1.51     Metoprolol
# 13      Laura    78      1.62      Enalapril
# 14     Alexis    26      1.74   Azitromicina
#              Barrio  Estrato  Precio Tratamiento Completo (USD)
# 0             Belén        4                              86.40
# 1          Laureles        5                             108.23
# ...

# %%
Pacientes_Info_Primaria2 = pd.DataFrame ([
    ['Marcela', 85, 1.68, 'Losartán'],
    ['José', 20, 1.80, 'Sertralina'],
    ['Fernando', 39, 1.60, 'Metformina'],
    ['Camila', 15, 1.45, 'Omeprazol'],
    ['Luisa', 44, 1.65, 'Atenolol'],
    ['Estefanía', 56, 1.55, 'Insulina'],
    ['Orlando', 67, 1.78, 'Atorvastatina'],
    ['Socorro', 9, 1.37, 'Paracetamol'],
    ['Ashley', 23, 1.70, 'Clonazepam'],
    ['William', 33, 1.82, 'Pregabalina'],
    ['Manuela', 50, 1.50, 'Furosemida'],
    ['Esteban', 10, 1.32, 'Loratadina'],
    ['Juan', 67, 1.51, 'Metoprolol'],
    ['Laura', 78, 1.62, 'Enalapril'],
    ['Alexis', 26, 1.74, 'Azitromicina']
    ], columns=['Nombre', 'Edad', 'Estatura', 'Medicamento'])

Pacientes_Info_Secundaria2 = pd.DataFrame ([
    ['Belén', 4, 86.40],
    ['Laureles', 5, 108.23],
    ['Aranjuez', 2, 72.70],
    ['Robledo', 3, 64.80],
    ['Buenos Aires', 2, 82.80],
    ['Castilla', 2, 316.80],
    ['Poblado', 6, 118.80],
    ['Villa Hermosa', 2, 46.80],
    ['San Javier', 2, 100.50],
    ['Doce de Octubre', 2, 190.80],
    ['Villa Hermosa', 2, 57.60],
    ['Santa Cruz', 2, 72.50],
    ['Colores', 4, 72.50],
    ['San Javier', 2, 79.20],
    ['Belén', 4, 86.40]
    ], columns=['Barrio', 'Estrato', 'Precio Tratamiento Completo (USD)'])

Prod_Farmacia2 = pd.DataFrame ([
    ['Losartán', 'Antihipertensivo', 120, 0.24],
    ['Sertralina', 'Antidepresivo', 80, 0.30],
    ['Metformina', 'Antidiabético', 150, 0.20],
    ['Omeprazol', 'Gastroprotector', 200, 0.18],
    ['Atenolol', 'Betabloqueador', 90, 0.23],
    ['Insulina', 'Antidiabético', 60, 0.88],
    ['Atorvastatina', 'Anticolesterol', 110, 0.33],
    ['Paracetamol', 'Analgésico', 300, 0.13],
    ['Clonazepam', 'Ansiolítico', 100, 0.28],
    ['Pregabalina', 'Neuropático', 70, 0.53],
    ['Furosemida', 'Diurético', 130, 0.16],
    ['Loratadina', 'Antialérgico', 180, 0.20],
    ['Metoprolol', 'Betabloqueador', 95, 0.20],
    ['Enalapril', 'Antihipertensivo', 105, 0.22],
    ['Azitromicina', 'Antibiótico', 85, 0.24]
    ], columns=['Medicamento', 'Tipo', 'Stock', 'Precio Unitario USD'])

print(Pacientes_Info_Primaria2)
print(Pacientes_Info_Secundaria2)
print(Prod_Farmacia2)
# Out:
#        Nombre  Edad  Estatura    Medicamento
# 0     Marcela    85      1.68       Losartán
# 1        José    20      1.80     Sertralina
# 2    Fernando    39      1.60     Metformina
# 3      Camila    15      1.45      Omeprazol
# 4       Luisa    44      1.65       Atenolol
# 5   Estefanía    56      1.55       Insulina
# 6     Orlando    67      1.78  Atorvastatina
# 7     Socorro     9      1.37    Paracetamol
# 8      Ashley    23      1.70     Clonazepam
# 9     William    33      1.82    Pregabalina
# 10    Manuela    50      1.50     Furosemida
# 11    Esteban    10      1.32     Loratadina
# 12       Juan    67      1.51     Metoprolol
# 13      Laura    78      1.62      Enalapril
# 14     Alexis    26      1.74   Azitromicina
#              Barrio  Estrato  Precio Tratamiento Completo (USD)
# 0             Belén        4                              86.40
# 1          Laureles        5                             108.23
# ...

# %%
Pacientes_Info_Primaria1.head()
# Out:
#      Nombre  Edad  Estatura Medicamento
# 0   Marcela    85      1.68    Losartán
# 1      José    20      1.80  Sertralina
# 2  Fernando    39      1.60  Metformina
# 3    Camila    15      1.45   Omeprazol
# 4     Luisa    44      1.65    Atenolol

# %%
Pacientes_Info_Secundaria1.head()
# Out:
#          Barrio  Estrato  Precio Tratamiento Completo (USD)
# 0         Belén        4                              86.40
# 1      Laureles        5                             108.23
# 2      Aranjuez        2                              72.70
# 3       Robledo        3                              64.80
# 4  Buenos Aires        2                              82.80

# %%
Prod_Farmacia1.head()
# Out:
#   Medicamento              Tipo  Stock  Precio_Unitario_USD
# 0    Losartán  Antihipertensivo    120                 0.24
# 1  Sertralina     Antidepresivo     80                 0.30
# 2  Metformina     Antidiabético    150                 0.20
# 3   Omeprazol   Gastroprotector    200                 0.18
# 4    Atenolol    Betabloqueador     90                 0.23

# %%
Pacientes_Info_Primaria1.tail()
# Out:
#      Nombre  Edad  Estatura   Medicamento
# 10  Manuela    50      1.50    Furosemida
# 11  Esteban    10      1.32    Loratadina
# 12     Juan    67      1.51    Metoprolol
# 13    Laura    78      1.62     Enalapril
# 14   Alexis    26      1.74  Azitromicina

# %%
Pacientes_Info_Secundaria1.tail()
# Out:
#            Barrio  Estrato  Precio Tratamiento Completo (USD)
# 10  Villa Hermosa        2                               57.6
# 11     Santa Cruz        2                               72.5
# 12        Colores        4                               72.5
# 13     San Javier        2                               79.2
# 14          Belén        4                               86.4

# %%
Prod_Farmacia1.tail()
# Out:
#      Medicamento              Tipo  Stock  Precio_Unitario_USD
# 10    Furosemida         Diurético    130                 0.16
# 11    Loratadina      Antialérgico    180                 0.20
# 12    Metoprolol    Betabloqueador     95                 0.20
# 13     Enalapril  Antihipertensivo    105                 0.22
# 14  Azitromicina       Antibiótico     85                 0.24

# %%
Pacientes_Info_Primaria1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       15 non-null     object
#  1   Edad         15 non-null     int64
#  2   Estatura     15 non-null     float64
#  3   Medicamento  15 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 612.0+ bytes

# %%
Pacientes_Info_Secundaria1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Barrio                             15 non-null     object
#  1   Estrato                            15 non-null     int64
#  2   Precio Tratamiento Completo (USD)  15 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 492.0+ bytes

# %%
Prod_Farmacia1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Medicamento          15 non-null     object
#  1   Tipo                 15 non-null     object
#  2   Stock                15 non-null     int64
#  3   Precio_Unitario_USD  15 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 612.0+ bytes

# %%
Pacientes_Info_Primaria1.dtypes
# Out:
# Nombre          object
# Edad             int64
# Estatura       float64
# Medicamento     object
# dtype: object

# %%
Pacientes_Info_Secundaria1.dtypes
# Out:
# Barrio                                object
# Estrato                                int64
# Precio Tratamiento Completo (USD)    float64
# dtype: object

# %%
Prod_Farmacia1.dtypes
# Out:
# Medicamento             object
# Tipo                    object
# Stock                    int64
# Precio_Unitario_USD    float64
# dtype: object

# %%
Pacientes_Info_Primaria1.columns = ['Nombre del Paciente', 'Años Cumplidos', 'Estatura', 'Medicamento Recetado']
Pacientes_Info_Secundaria1.columns = ['Zona de Vivienda', 'Estrato SocioEconómico', 'Precio Tratamiento (USD)']
Prod_Farmacia1.columns = ['Medicamento', 'Tipo de Medicamento', 'Stock Disponible', 'Precio por Unidad (USD)']

print(Pacientes_Info_Primaria1)
print(Pacientes_Info_Secundaria1)
print(Prod_Farmacia1)
# Out:
#    Nombre del Paciente  Años Cumplidos  Estatura Medicamento Recetado
# 0              Marcela              85      1.68             Losartán
# 1                 José              20      1.80           Sertralina
# 2             Fernando              39      1.60           Metformina
# 3               Camila              15      1.45            Omeprazol
# 4                Luisa              44      1.65             Atenolol
# 5            Estefanía              56      1.55             Insulina
# 6              Orlando              67      1.78        Atorvastatina
# 7              Socorro               9      1.37          Paracetamol
# 8               Ashley              23      1.70           Clonazepam
# 9              William              33      1.82          Pregabalina
# 10             Manuela              50      1.50           Furosemida
# 11             Esteban              10      1.32           Loratadina
# ...

# %%
names1 = Pacientes_Info_Primaria1['Medicamento Recetado']
names2 = Pacientes_Info_Secundaria1['Precio Tratamiento (USD)']
names3 = Prod_Farmacia1['Tipo de Medicamento']

print(names1)
print(names2)
print(names3)
# Out:
# 0          Losartán
# 1        Sertralina
# 2        Metformina
# 3         Omeprazol
# 4          Atenolol
# 5          Insulina
# 6     Atorvastatina
# 7       Paracetamol
# 8        Clonazepam
# 9       Pregabalina
# 10       Furosemida
# 11       Loratadina
# 12       Metoprolol
# 13        Enalapril
# 14     Azitromicina
# Name: Medicamento Recetado, dtype: object
# 0      86.40
# 1     108.23
# 2      72.70
# 3      64.80
# 4      82.80
# 5     316.80
# 6     118.80
# 7      46.80
# 8     100.50
# 9     190.80
# 10     57.60
# 11     72.50
# 12     72.50
# 13     79.20
# 14     86.40
# Name: Precio Tratamiento (USD), dtype: float64
# 0     Antihipertensivo
# 1        Antidepresivo
# 2        Antidiabético
# 3      Gastroprotector
# 4       Betabloqueador
# 5        Antidiabético
# 6       Anticolesterol
# 7           Analgésico
# 8          Ansiolítico
# 9          Neuropático
# 10           Diurético
# 11        Antialérgico
# 12      Betabloqueador
# 13    Antihipertensivo
# ...

# %%
Pacientes_Info_Primaria1[['Nombre del Paciente', 'Medicamento Recetado']]
# Out:
#    Nombre del Paciente Medicamento Recetado
# 0              Marcela             Losartán
# 1                 José           Sertralina
# 2             Fernando           Metformina
# 3               Camila            Omeprazol
# 4                Luisa             Atenolol
# 5            Estefanía             Insulina
# 6              Orlando        Atorvastatina
# 7              Socorro          Paracetamol
# 8               Ashley           Clonazepam
# 9              William          Pregabalina
# 10             Manuela           Furosemida
# 11             Esteban           Loratadina
# 12                Juan           Metoprolol
# 13               Laura            Enalapril
# 14              Alexis         Azitromicina

# %%
Pacientes_Info_Secundaria1[['Zona de Vivienda', 'Estrato SocioEconómico']]
# Out:
#    Zona de Vivienda  Estrato SocioEconómico
# 0             Belén                       4
# 1          Laureles                       5
# 2          Aranjuez                       2
# 3           Robledo                       3
# 4      Buenos Aires                       2
# 5          Castilla                       2
# 6           Poblado                       6
# 7     Villa Hermosa                       2
# 8        San Javier                       2
# 9   Doce de Octubre                       2
# 10    Villa Hermosa                       2
# 11       Santa Cruz                       2
# 12          Colores                       4
# 13       San Javier                       2
# 14            Belén                       4

# %%
Prod_Farmacia1[['Tipo de Medicamento', 'Precio por Unidad (USD)']]
# Out:
#    Tipo de Medicamento  Precio por Unidad (USD)
# 0     Antihipertensivo                     0.24
# 1        Antidepresivo                     0.30
# 2        Antidiabético                     0.20
# 3      Gastroprotector                     0.18
# 4       Betabloqueador                     0.23
# 5        Antidiabético                     0.88
# 6       Anticolesterol                     0.33
# 7           Analgésico                     0.13
# 8          Ansiolítico                     0.28
# 9          Neuropático                     0.53
# 10           Diurético                     0.16
# 11        Antialérgico                     0.20
# 12      Betabloqueador                     0.20
# 13    Antihipertensivo                     0.22
# 14         Antibiótico                     0.24

# %%
Años_Cumplidos = Pacientes_Info_Primaria1[Pacientes_Info_Primaria1['Años Cumplidos'] > 50]
Estrato = Pacientes_Info_Secundaria1[Pacientes_Info_Secundaria1['Estrato SocioEconómico'] <= 3]
Precio_Unitario = Prod_Farmacia1[Prod_Farmacia1['Precio por Unidad (USD)'] <= 0.20]

print(Años_Cumplidos)
print(Estrato)
print(Precio_Unitario)
# Out:
#    Nombre del Paciente  Años Cumplidos  Estatura Medicamento Recetado
# 0              Marcela              85      1.68             Losartán
# 5            Estefanía              56      1.55             Insulina
# 6              Orlando              67      1.78        Atorvastatina
# 12                Juan              67      1.51           Metoprolol
# 13               Laura              78      1.62            Enalapril
#    Zona de Vivienda  Estrato SocioEconómico  Precio Tratamiento (USD)
# 2          Aranjuez                       2                      72.7
# 3           Robledo                       3                      64.8
# 4      Buenos Aires                       2                      82.8
# 5          Castilla                       2                     316.8
# 7     Villa Hermosa                       2                      46.8
# 8        San Javier                       2                     100.5
# ...

# %%
Pacientes_Info_Primaria1.loc [8]
# Out:
# Nombre del Paciente         Ashley
# Años Cumplidos                  23
# Estatura                       1.7
# Medicamento Recetado    Clonazepam
# Name: 8, dtype: object

# %%
Pacientes_Info_Secundaria1.loc [14]
# Out:
# Zona de Vivienda            Belén
# Estrato SocioEconómico          4
# Precio Tratamiento (USD)     86.4
# Name: 14, dtype: object

# %%
Prod_Farmacia1.iloc[4]
# Out:
# Medicamento                      Atenolol
# Tipo de Medicamento        Betabloqueador
# Stock Disponible                       90
# Precio por Unidad (USD)              0.23
# Name: 4, dtype: object

# %%
Or = Pacientes_Info_Primaria1[(Pacientes_Info_Primaria1['Años Cumplidos'] >= 40) | (Pacientes_Info_Primaria1['Estatura'] > 1.50)]
Y = Pacientes_Info_Secundaria1[(Pacientes_Info_Secundaria1['Estrato SocioEconómico'] <= 2) & (Pacientes_Info_Secundaria1['Precio Tratamiento (USD)'] > 100)]

print(Or)
print(Y)
# Out:
#    Nombre del Paciente  Años Cumplidos  Estatura Medicamento Recetado
# 0              Marcela              85      1.68             Losartán
# 1                 José              20      1.80           Sertralina
# 2             Fernando              39      1.60           Metformina
# 4                Luisa              44      1.65             Atenolol
# 5            Estefanía              56      1.55             Insulina
# 6              Orlando              67      1.78        Atorvastatina
# 8               Ashley              23      1.70           Clonazepam
# 9              William              33      1.82          Pregabalina
# 10             Manuela              50      1.50           Furosemida
# 12                Juan              67      1.51           Metoprolol
# 13               Laura              78      1.62            Enalapril
# 14              Alexis              26      1.74         Azitromicina
# ...

# %%
Pacientes_Info_Primaria1['Años Cumplidos'] = [24, 46, 18, 38, 27, 59, 60, 70, 28, 49, 61, 42, 89, 76, 52]
Pacientes_Info_Secundaria1['Estrato SocioEconómico'] = [3, 6, 1, 4, 6, 6, 5, 3, 4, 3, 5, 1, 2, 5, 2]
Prod_Farmacia1['Stock Disponible'] = [20, 280, 50, 100, 10, 38, 124, 94, 56, 82, 500, 3, 84, 45, 92]

print(Pacientes_Info_Primaria1)
print(Pacientes_Info_Secundaria1)
print(Prod_Farmacia1)
# Out:
#    Nombre del Paciente  Años Cumplidos  Estatura Medicamento Recetado
# 0              Marcela              24      1.68             Losartán
# 1                 José              46      1.80           Sertralina
# 2             Fernando              18      1.60           Metformina
# 3               Camila              38      1.45            Omeprazol
# 4                Luisa              27      1.65             Atenolol
# 5            Estefanía              59      1.55             Insulina
# 6              Orlando              60      1.78        Atorvastatina
# 7              Socorro              70      1.37          Paracetamol
# 8               Ashley              28      1.70           Clonazepam
# 9              William              49      1.82          Pregabalina
# 10             Manuela              61      1.50           Furosemida
# 11             Esteban              42      1.32           Loratadina
# ...

# %%
Pacientes_Info_Primaria1['Años Cumplidos'].mean()
# Out:
# np.float64(49.266666666666666)

# %%
Pacientes_Info_Secundaria1['Estrato SocioEconómico'].mean()
# Out:
# np.float64(3.7333333333333334)

# %%
Prod_Farmacia1['Stock Disponible'].mean()
# Out:
# np.float64(105.2)

# %%
Pacientes_Info_Primaria1['Años Cumplidos'].median()
# Out:
# 49.0

# %%
Pacientes_Info_Secundaria1['Estrato SocioEconómico'].median()
# Out:
# 4.0

# %%
Prod_Farmacia1['Stock Disponible'].median()
# Out:
# 82.0

# %%
Pacientes_Info_Primaria1['Años Cumplidos'].std()
# Out:
# 20.411714656983015

# %%
Pacientes_Info_Secundaria1['Estrato SocioEconómico'].std()
# Out:
# 1.7511900715418263

# %%
Prod_Farmacia1['Stock Disponible'].std()
# Out:
# 127.74539410204078

# %%
Pacientes_Info_Primaria1['Años Cumplidos'].max()
# Out:
# 89

# %%
Pacientes_Info_Secundaria1['Estrato SocioEconómico'].max()
# Out:
# 6

# %%
Prod_Farmacia1['Stock Disponible'].max()
# Out:
# 500

# %%
Pacientes_Info_Primaria1['Años Cumplidos'].min()
# Out:
# 18

# %%
Pacientes_Info_Secundaria1['Estrato SocioEconómico'].min()
# Out:
# 1

# %%
Prod_Farmacia1['Stock Disponible'].min()
# Out:
# 3

# %%
Pacientes_Info_Primaria1['Años Cumplidos'].describe()
# Out:
# count    15.000000
# mean     49.266667
# std      20.411715
# min      18.000000
# 25%      33.000000
# 50%      49.000000
# 75%      60.500000
# max      89.000000
# Name: Años Cumplidos, dtype: float64

# %%
Pacientes_Info_Secundaria1['Estrato SocioEconómico'].describe()
# Out:
# count    15.000000
# mean      3.733333
# std       1.751190
# min       1.000000
# 25%       2.500000
# 50%       4.000000
# 75%       5.000000
# max       6.000000
# Name: Estrato SocioEconómico, dtype: float64

# %%
Prod_Farmacia1['Stock Disponible'].describe()
# Out:
# count     15.000000
# mean     105.200000
# std      127.745394
# min        3.000000
# 25%       41.500000
# 50%       82.000000
# 75%       97.000000
# max      500.000000
# Name: Stock Disponible, dtype: float64

# %%
Pacientes_Info_Primaria1 = Pacientes_Info_Primaria1.drop(columns=['Estatura'])
Pacientes_Info_Secundaria1 = Pacientes_Info_Secundaria1.drop(columns=['Estrato SocioEconómico'])
Prod_Farmacia1 = Prod_Farmacia1.drop(columns=['Precio por Unidad (USD)'])

print(Pacientes_Info_Primaria1)
print(Pacientes_Info_Secundaria1)
print(Prod_Farmacia1)
# Out:
#    Nombre del Paciente  Años Cumplidos Medicamento Recetado
# 0              Marcela              24             Losartán
# 1                 José              46           Sertralina
# 2             Fernando              18           Metformina
# 3               Camila              38            Omeprazol
# 4                Luisa              27             Atenolol
# 5            Estefanía              59             Insulina
# 6              Orlando              60        Atorvastatina
# 7              Socorro              70          Paracetamol
# 8               Ashley              28           Clonazepam
# 9              William              49          Pregabalina
# 10             Manuela              61           Furosemida
# 11             Esteban              42           Loratadina
# 12                Juan              89           Metoprolol
# 13               Laura              76            Enalapril
# 14              Alexis              52         Azitromicina
# ...

# %%
Pacientes_Info_Primaria1 = Pacientes_Info_Primaria1.drop(index=7)
Pacientes_Info_Secundaria1 = Pacientes_Info_Secundaria1.drop(index=13)
Prod_Farmacia1 = Prod_Farmacia1.drop(index=10)

print(Pacientes_Info_Primaria1)
print(Pacientes_Info_Secundaria1)
print(Prod_Farmacia1)
# Out:
#    Nombre del Paciente  Años Cumplidos Medicamento Recetado
# 0              Marcela              24             Losartán
# 1                 José              46           Sertralina
# 2             Fernando              18           Metformina
# 3               Camila              38            Omeprazol
# 4                Luisa              27             Atenolol
# 5            Estefanía              59             Insulina
# 6              Orlando              60        Atorvastatina
# 8               Ashley              28           Clonazepam
# 9              William              49          Pregabalina
# 10             Manuela              61           Furosemida
# 11             Esteban              42           Loratadina
# 12                Juan              89           Metoprolol
# 13               Laura              76            Enalapril
# 14              Alexis              52         Azitromicina
#    Zona de Vivienda  Precio Tratamiento (USD)
# ...
