# %% [markdown]
# <a href="https://colab.research.google.com/github/Laurarpoa/Grupo-de-trabajo-/blob/main/Parcial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Usar un estilo moderno
plt.style.use("seaborn-v0_8")

# Datos
meses = ["Ene", "Feb", "Mar", "Abr", "May", "Jun", "Jul", "Ago", "Sep", "Oct", "Nov", "Dic"]
temperaturas = [22, 24, 27, 30, 32, 35, 34, 33, 30, 27, 24, 22]

# Crear figura
plt.figure(figsize=(10, 6))

# Graficar línea
plt.plot(meses, temperaturas, color='red', marker='o', linewidth=2.5, markersize=8, alpha=0.85)

# Rellenar debajo de la línea
plt.fill_between(meses, temperaturas, color='red', alpha=0.1)

# Título y etiquetas con estilo
plt.title("📊 Temperatura media mensual", fontsize=20, fontweight='bold', color='darkred', pad=20)
plt.xlabel("Mes", fontsize=14, fontweight='bold', labelpad=10, color='dimgray')
plt.ylabel("Temperatura (°C)", fontsize=14, fontweight='bold', labelpad=10, color='dimgray')

# Ajustar ticks
plt.xticks(fontsize=12, color='black')
plt.yticks(fontsize=12, color='black')

# Activar grid
plt.grid(True, linestyle='--', alpha=0.6)

# Mostrar gráfico
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Liberation Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Estilo de Seaborn
sns.set_style("whitegrid")

# Datos simulados
np.random.seed(42)
edades = np.random.randint(20, 60, size=20)
ingresos = np.random.randint(1000, 5000, size=20)
generos = np.random.choice(["Masculino", "Femenino"], size=20)

# Crear DataFrame
df = pd.DataFrame({
    "Edad": edades,
    "Ingreso Mensual": ingresos,
    "Género": generos
})

# Crear scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=df,
    x="Edad",
    y="Ingreso Mensual",
    hue="Género",
    s=100,
    palette="coolwarm"
)

# Título y etiquetas personalizadas
plt.title("Relación entre Edad e Ingreso Mensual", fontsize=16, fontweight='bold', pad=15)
plt.xlabel("Edad (años)", fontsize=14, fontweight='bold')
plt.ylabel("Ingreso Mensual (USD)", fontsize=14, fontweight='bold')

# Mostrar gráfico
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# Generar datos aleatorios con distribución normal
np.random.seed(42)  # Para reproducibilidad
datos = np.random.normal(loc=50, scale=10, size=200)

# Crear histograma
plt.figure(figsize=(8, 6))
plt.hist(datos, bins=15, color='blue', alpha=0.6, edgecolor='black')

# Título y etiquetas
plt.title("Distribución de datos (Normal, μ=50, σ=10)", fontsize=16, fontweight='bold')
plt.xlabel("Valor", fontsize=14, fontweight='bold')
plt.ylabel("Frecuencia", fontsize=14, fontweight='bold')

# Mostrar gráfico
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Estilo de Seaborn
sns.set_style("whitegrid")

# Generar datos sintéticos
np.random.seed(42)
ninos = np.random.normal(loc=130, scale=10, size=30)        # Media 130 cm, desviación 10
adultos = np.random.normal(loc=170, scale=8, size=30)       # Media 170 cm, desviación 8
adultos_mayores = np.random.normal(loc=165, scale=9, size=30)  # Media 165 cm, desviación 9

# Crear DataFrame
df = pd.DataFrame({
    "Altura": np.concatenate([ninos, adultos, adultos_mayores]),
    "Grupo": ["Niños"]*30 + ["Adultos"]*30 + ["Adultos Mayores"]*30
})

# Crear boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(
    data=df,
    x="Grupo",
    y="Altura",
    palette="Set2",      # Colores automáticos
    showfliers=True      # Mostrar outliers
)

# Título y etiquetas
plt.title("Comparación de alturas por grupo", fontsize=16, fontweight='bold')
plt.xlabel("Grupo", fontsize=14, fontweight='bold')
plt.ylabel("Altura (cm)", fontsize=14, fontweight='bold')

# Mostrar gráfico
plt.show()
# Out:
# /tmp/ipython-input-2498037097.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Estilo
sns.set_style("whitegrid")

# Generar datos sintéticos
np.random.seed(42)
meses = [f"Mes {i}" for i in range(1, 13)]
regiones = ["Norte", "Centro", "Sur"]

# Crear DataFrame
data = []
for mes in meses:
    for region in regiones:
        ventas = np.random.randint(1000, 5000)
        data.append([mes, region, ventas])

df = pd.DataFrame(data, columns=["Mes", "Region", "Ventas"])

# Calcular promedio móvil (agrupando por mes)
ventas_totales_mes = df.groupby("Mes")["Ventas"].sum().reset_index()
ventas_totales_mes["Promedio_Movil"] = ventas_totales_mes["Ventas"].rolling(window=3).mean()

# Crear figura
plt.figure(figsize=(10, 6))

# Barras de ventas por región
sns.barplot(
    data=df,
    x="Mes",
    y="Ventas",
    hue="Region",
    palette="Set2"
)

# Línea del promedio móvil (sobre ventas totales)
plt.plot(
    ventas_totales_mes["Mes"],
    ventas_totales_mes["Promedio_Movil"],
    color="black",
    marker="o",
    linewidth=2,
    label="Promedio móvil"
)

# Título y etiquetas
plt.title("Ventas mensuales por región y promedio móvil", fontsize=16, fontweight='bold', pad=15)
plt.xlabel("Mes", fontsize=14, fontweight='bold')
plt.ylabel("Ventas", fontsize=14, fontweight='bold')

# Leyenda
plt.legend(title="Leyenda", labels=["Promedio móvil", "Norte", "Centro", "Sur"])

# Mejorar visibilidad
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar gráfico
plt.show()
